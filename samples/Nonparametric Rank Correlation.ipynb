# %% [markdown]
# # Calculando Rank de Correlação não paramétrico

# %%
import numpy as np

# generate related variables
from numpy.random import rand
from numpy.random import seed
from matplotlib import pyplot
# importing ecosystem scipy for statistics
from scipy import stats

# seed random number generator
seed(1)

# prepare data
data1 = rand(1000) * 20
data2 = data1 + (rand(1000) * 10)

# %% [markdown]
# ## Conjunto de dados1

# %%
data1
# Out:
# array([8.34044009e+00, 1.44064899e+01, 2.28749635e-03, 6.04665145e+00,
#        2.93511782e+00, 1.84677190e+00, 3.72520423e+00, 6.91121454e+00,
#        7.93534948e+00, 1.07763347e+01, 8.38389029e+00, 1.37043900e+01,
#        4.08904499e+00, 1.75623487e+01, 5.47751864e-01, 1.34093502e+01,
#        8.34609605e+00, 1.11737966e+01, 2.80773877e+00, 3.96202978e+00,
#        1.60148914e+01, 1.93652315e+01, 6.26848356e+00, 1.38464523e+01,
#        1.75277830e+01, 1.78921333e+01, 1.70088423e+00, 7.81095665e-01,
#        3.39660839e+00, 1.75628501e+01, 1.96693668e+00, 8.42215250e+00,
#        1.91577906e+01, 1.06633057e+01, 1.38375423e+01, 6.31031262e+00,
#        1.37300186e+01, 1.66925134e+01, 3.65765547e-01, 1.50028863e+01,
#        1.97772218e+01, 1.49633131e+01, 5.60887984e+00, 1.57855866e+01,
#        2.06452013e+00, 8.95787052e+00, 1.81719101e+01, 5.87228297e+00,
#        5.75550677e+00, 2.60057144e+00, 3.87339157e-01, 1.35767107e+01,
# ...

# %%
type(data1)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Conjunto de Dados 2

# %%
data2
# Out:
# array([11.59853976, 23.30476328,  7.51936471, 13.67297241,  7.6299081 ,
#         3.95441692,  4.13995502, 10.12950254,  8.30647613, 17.71488879,
#        15.08739061, 18.00910784, 11.76693477, 22.92243368,  0.94635113,
#        14.75728138, 10.28026004, 14.53043458,  3.33086824, 10.01319759,
#        21.13550165, 25.53984163, 10.59203951, 22.323457  , 22.06837361,
#        18.04616847, 10.43156571,  7.34311114, 11.6266388 , 27.080607  ,
#         2.47606051, 10.77287114, 19.79122504, 14.87988456, 22.47583373,
#         7.12655245, 18.46113808, 17.94794454,  8.09462157, 23.41710787,
#        20.21013116, 19.82772052,  8.00299028, 25.31032439, 11.50344641,
#        15.09721055, 27.90678404,  9.3208964 , 14.73401395,  6.94652118,
#         2.74548553, 22.98499029, 11.07474283,  5.96004904, 18.53571175,
#         8.08105385, 17.53162084, 10.25832049, 14.32050116, 20.00005675,
#        10.19288039,  8.82225636, 15.19310987, 16.70804349,  7.18252787,
# ...

# %%
type(data2)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Gerando o Gráfico de Correlação entre data1 e data2 (via scatter plot)

# %%
# plot
pyplot.scatter(data1, data2)
pyplot.show()

# %%
# calculate spearman's correlation
coef, p = stats.spearmanr(data1, data2)

# %%
coef
# Out:
# 0.900003924003924

# %%
p
# Out:
# 0.0

# %% [markdown]
# ## Cálculo do Coeficiente de Correlação Spearman

# %%
print('Spearmans correlation coefficient: %.3f' % coef)
# interpret the significance
alpha = 0.05
if p > alpha:
	print('Samples are uncorrelated (fail to reject H0) p=%.3f' % p)
else:
	print('Samples are correlated (reject H0) p=%.3f' % p)
# Out:
# Spearmans correlation coefficient: 0.900
# Samples are correlated (reject H0) p=0.000

# %% [markdown]
# ## --------

# %%
array1 = np.array([1,2,3])

# %%
array1 = np.append(array1, 5)

# %%
array1
# Out:
# array([1, 2, 3, 5])

# %%
print('array1[0]:', array1[0], 'array1[1]:', array1[1], 'array1[2]:', array1[2])
# Out:
# array1[0]: 1 array1[1]: 2 array1[2]: 3

# %%
array1[3]
# Out:
# 5
